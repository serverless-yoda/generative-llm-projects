# %%
# %pip install langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (2.0.1)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from langchain-google-genai) (0.8.2)
# Requirement already satisfied: langchain-core<0.4,>=0.3.0 in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from langchain-google-genai) (0.3.12)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from langchain-google-genai) (2.6.1)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.6.10)
# Requirement already satisfied: google-api-core in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.17.0)
# Requirement already satisfied: google-api-python-client in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.116.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.27.0)
# Requirement already satisfied: protobuf in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.25.2)
# Requirement already satisfied: tqdm in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.23.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai) (0.1.129)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai) (23.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from langchain-core<0.4,>=0.3.0->langchain-google-genai) (8.2.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.16.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.62.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.0->langchain-google-genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (0.26.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (3.10.7)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.1.1)
# Requirement already satisfied: colorama in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from tqdm->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.60.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.60.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.1.4)
# Requirement already satisfied: anyio in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (4.6.0)
# Requirement already satisfied: certifi in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\ma2\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (1.0.2)
# Requirement already satisfied: idna in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (3.10)
# Requirement already satisfied: sniffio in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ma2\appdata\roaming\python\python311\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ma2\.conda\envs\generative-llm-projects\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai
import os
from dotenv import load_dotenv

from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain_google_genai import GoogleGenerativeAIEmbeddings

from langchain.vectorstores import DeepLake
# Out:
# c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\util\check_latest_version.py:32: UserWarning: A newer version of deeplake (4.0.1) is available. It's recommended that you update to the latest version using `pip install -U deeplake`.
#   warnings.warn(

# %%
_ = load_dotenv()
openai.api_key = os.environ['OPENAI_API_KEY']

gemini_embedding = GoogleGenerativeAIEmbeddings(model='models/embedding-001')

# %%
source_text = './contents/llm.txt'
dataset_path = os.environ['ACTIVELOOP_DATASET']

CHUNK_SIZE=1000
CHUNK_OVERLAP=200

# %%
documents = TextLoader(source_text).load() 
text_splitter = RecursiveCharacterTextSplitter(
                    chunk_size=CHUNK_SIZE,
                    chunk_overlap=CHUNK_OVERLAP, 
                    separators=["\n\n", "\n", ".", "!", "?", ",", " ", ""])

docs = text_splitter.split_documents(documents) 

db = DeepLake.from_documents(docs, dataset_path=dataset_path, embedding=gemini_embedding)
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFoundException                 Traceback (most recent call last)
# Cell In[12], line 9
#       2 text_splitter = RecursiveCharacterTextSplitter(
#       3                     chunk_size=CHUNK_SIZE,
#       4                     chunk_overlap=CHUNK_OVERLAP,
#       5                     separators=["\n\n", "\n", ".", "!", "?", ",", " ", ""])
#       7 docs = text_splitter.split_documents(documents)
# ----> 9 db = DeepLake.from_documents(docs, dataset_path=dataset_path, embedding=gemini_embedding)
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\langchain_core\vectorstores\base.py:852, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     849     if any(ids):
#     850         kwargs["ids"] = ids
# --> 852 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\langchain_community\vectorstores\deeplake.py:874, in DeepLake.from_texts(cls, texts, embedding, metadatas, ids, dataset_path, **kwargs)
#     824 @classmethod
#     825 def from_texts(
#     826     cls,
#    (...)
#     832     **kwargs: Any,
#     833 ) -> DeepLake:
#     834     """Create a Deep Lake dataset from a raw documents.
#     835
#     836     If a dataset_path is specified, the dataset will be persisted in that location,
#    (...)
#     872         DeepLake: Deep Lake dataset.
#     873     """
# --> 874     deeplake_dataset = cls(dataset_path=dataset_path, embedding=embedding, **kwargs)
#     875     deeplake_dataset.add_texts(
#     876         texts=texts,
#     877         metadatas=metadatas,
#     878         ids=ids,
#     879     )
#     880     return deeplake_dataset
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\langchain_community\vectorstores\deeplake.py:192, in DeepLake.__init__(self, dataset_path, token, embedding, embedding_function, read_only, ingestion_batch_size, num_workers, verbose, exec_option, runtime, index_params, **kwargs)
#     186 if embedding_function:
#     187     logger.warning(
#     188         "Using embedding function is deprecated and will be removed "
#     189         "in the future. Please use embedding instead."
#     190     )
# --> 192 self.vectorstore = DeepLakeVectorStore(
#     193     path=self.dataset_path,
#     194     embedding_function=embedding_function or embedding,
#     195     read_only=read_only,
#     196     token=token,
#     197     exec_option=exec_option,
#     198     verbose=verbose,
#     199     runtime=runtime,
#     200     index_params=index_params,
#     201     **kwargs,
#     202 )
#     204 self._embedding_function = embedding_function or embedding
#     205 self._id_tensor_name = "ids" if "ids" in self.vectorstore.tensors() else "id"
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\core\vectorstore\deeplake_vectorstore.py:120, in VectorStore.__init__(self, path, dataset, tensor_params, embedding_function, read_only, ingestion_batch_size, index_params, exec_option, token, overwrite, verbose, runtime, creds, org_id, logger, branch, indra, **kwargs)
#      48 """Creates an empty VectorStore or loads an existing one if it exists at the specified ``path``.
#      49
#      50 Examples:
#    (...)
#     115     Setting ``overwrite`` to ``True`` will delete all of your data if the Vector Store exists! Be very careful when setting this parameter.
#     116 """
#     118 kwargs.pop("num_workers", None)
# --> 120 self.dataset_handler = get_dataset_handler(
#     121     path=path,
#     122     dataset=dataset,
#     123     tensor_params=tensor_params,
#     124     embedding_function=embedding_function,
#     125     read_only=read_only,
#     126     ingestion_batch_size=ingestion_batch_size,
#     127     index_params=index_params,
#     128     num_workers=0,
#     129     exec_option=exec_option,
#     130     token=token,
#     131     overwrite=overwrite,
#     132     verbose=verbose,
#     133     runtime=runtime,
#     134     creds=creds,
#     135     org_id=org_id,
#     136     logger=logger,
#     137     branch=branch,
#     138     **kwargs,
#     139 )
#     141 self.deep_memory = DeepMemory(
#     142     dataset=self.dataset_handler.dataset,
#     143     path=self.dataset_handler.path,
#    (...)
#     147     creds=self.dataset_handler.creds,
#     148 )
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\core\vectorstore\dataset_handlers\dataset_handler.py:13, in get_dataset_handler(*args, **kwargs)
#       6 def get_dataset_handler(*args, **kwargs):
#       7     # TODO: Use this logic when managed db will be ready
#       8     # runtime = kwargs.get("runtime", None)
#    (...)
#      11     # else:
#      12     #     return ClientSideDH(*args, **kwargs)
# ---> 13     return ClientSideDH(*args, **kwargs)
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\core\vectorstore\dataset_handlers\client_side_dataset_handler.py:66, in ClientSideDH.__init__(self, path, dataset, tensor_params, embedding_function, read_only, ingestion_batch_size, index_params, num_workers, exec_option, token, overwrite, verbose, runtime, creds, org_id, logger, branch, **kwargs)
#      64 self.index_params = utils.parse_index_params(index_params)
#      65 kwargs["index_params"] = self.index_params
# ---> 66 self.dataset = dataset or dataset_utils.create_or_load_dataset(
#      67     tensor_params=tensor_params,
#      68     dataset_path=self.path,
#      69     token=self.token,
#      70     creds=self.creds,
#      71     logger=self.logger,
#      72     read_only=read_only,
#      73     exec_option=exec_option,
#      74     embedding_function=embedding_function,
#      75     overwrite=overwrite,
#      76     runtime=runtime,
#      77     org_id=self.org_id,
#      78     branch=branch,
#      79     **kwargs,
#      80 )
#      81 self.verbose = verbose
#      82 self.tensor_params = tensor_params
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\core\vectorstore\vector_search\dataset\dataset.py:43, in create_or_load_dataset(tensor_params, dataset_path, token, creds, logger, read_only, exec_option, embedding_function, overwrite, runtime, org_id, branch, **kwargs)
#      26 def create_or_load_dataset(
#      27     tensor_params,
#      28     dataset_path,
#    (...)
#      39     **kwargs,
#      40 ):
#      41     utils.check_indra_installation(exec_option=exec_option)
# ---> 43     if not overwrite and dataset_exists(dataset_path, token, creds, **kwargs):
#      44         if tensor_params is not None and tensor_params != DEFAULT_VECTORSTORE_TENSORS:
#      45             raise ValueError(
#      46                 "Vector Store is not empty. You shouldn't specify tensor_params if you're loading from existing dataset."
#      47             )
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\core\vectorstore\vector_search\dataset\dataset.py:78, in dataset_exists(dataset_path, token, creds, **kwargs)
#      76 def dataset_exists(dataset_path, token, creds, **kwargs):
#      77     return (
# ---> 78         deeplake.exists(dataset_path, token=token, creds=creds)
#      79         and "overwrite" not in kwargs
#      80     )
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\api\dataset.py:406, in dataset.exists(path, creds, token, org_id)
#     403 _fetch_creds_from_key(creds, org_id, token)
#     405 try:
# --> 406     storage, cache_chain = get_storage_and_cache_chain(
#     407         path=path,
#     408         read_only=True,
#     409         creds=creds,
#     410         token=token,
#     411         memory_cache_size=DEFAULT_MEMORY_CACHE_SIZE,
#     412         local_cache_size=DEFAULT_LOCAL_CACHE_SIZE,
#     413     )
#     414 except TokenPermissionError:
#     415     # Cloud Dataset does not exist
#     416     return False
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\util\storage.py:244, in get_storage_and_cache_chain(path, read_only, creds, token, memory_cache_size, local_cache_size, db_engine, indra)
#     216 def get_storage_and_cache_chain(
#     217     path,
#     218     read_only,
#    (...)
#     224     indra=False,
#     225 ):
#     226     """
#     227     Returns storage provider and cache chain for a given path, according to arguments passed.
#     228
#    (...)
#     241         A tuple of the storage provider and the storage chain.
#     242     """
# --> 244     storage = storage_provider_from_path(
#     245         path=path,
#     246         db_engine=db_engine,
#     247         creds=creds,
#     248         read_only=read_only,
#     249         token=token,
#     250         indra=indra,
#     251     )
#     252     memory_cache_size_bytes = memory_cache_size * MB
#     253     local_cache_size_bytes = local_cache_size * MB
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\util\storage.py:66, in storage_provider_from_path(path, creds, read_only, token, is_hub_path, db_engine, indra)
#      62     storage: StorageProvider = IndraProvider(
#      63         path, read_only=read_only, token=token, creds=creds
#      64     )
#      65 elif path.startswith("hub://"):
# ---> 66     storage = storage_provider_from_hub_path(
#      67         path, read_only, db_engine=db_engine, token=token, creds=creds
#      68     )
#      69 else:
#      70     if path.startswith("s3://"):
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\util\storage.py:164, in storage_provider_from_hub_path(path, read_only, db_engine, token, creds, indra)
#     161 client = DeepLakeBackendClient(token=token)
#     163 mode = None if (read_only is None) else ("r" if read_only else "w")
# --> 164 url, final_creds, mode, expiration, repo = get_dataset_credentials(
#     165     client, org_id, ds_name, mode, db_engine
#     166 )
#     168 is_local = get_path_type(url) == "local"
#     170 # ignore mode returned from backend if underlying storage is local
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\util\storage.py:141, in get_dataset_credentials(client, org_id, ds_name, mode, db_engine)
#     132 def get_dataset_credentials(
#     133     client: DeepLakeBackendClient,
#     134     org_id: str,
#    (...)
#     138 ):
#     139     # this will give the proper url(s3, gcs, etc) and corresponding creds, depending on where the dataset is stored.
#     140     try:
# --> 141         url, final_creds, mode, expiration, repo = client.get_dataset_credentials(
#     142             org_id, ds_name, mode=mode, db_engine={"enabled": db_engine}
#     143         )
#     144     except AgreementNotAcceptedError as e:
#     145         handle_dataset_agreements(client, e.agreements, org_id, ds_name)
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\client\client.py:190, in DeepLakeBackendClient.get_dataset_credentials(self, org_id, ds_name, mode, db_engine, no_cache)
#     188 relative_url = GET_DATASET_CREDENTIALS_SUFFIX.format(org_id, ds_name)
#     189 try:
# --> 190     response = self.request(
#     191         "GET",
#     192         relative_url,
#     193         endpoint=self.endpoint(),
#     194         params={
#     195             "mode": mode,
#     196             "no_cache": no_cache,
#     197             "db_engine": json.dumps(db_engine),
#     198         },
#     199     ).json()
#     200 except Exception as e:
#     201     if isinstance(e, AuthorizationException):
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\client\client.py:142, in DeepLakeBackendClient.request(self, method, relative_url, endpoint, params, data, files, json, headers, timeout)
#     140     status_code = response.status_code
#     141     tries += 1
# --> 142 check_response_status(response)
#     143 return response
#
# File c:\Users\ma2\.conda\envs\generative-llm-projects\Lib\site-packages\deeplake\client\utils.py:63, in check_response_status(response)
#      61 elif response.status_code == 404:
#      62     if message != " ":
# ---> 63         raise ResourceNotFoundException(message)
#      64     raise ResourceNotFoundException
#      65 elif response.status_code == 422:
#
# ResourceNotFoundException: Dataset at path hub://pythoninaction/space_exploration_v1 is scheduled for deletion.
